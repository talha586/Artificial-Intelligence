# %%
#QUESTION 1
def merge(l1, l2):
    res = []
    while len(l1) > 0 and len(l2) > 0:
    {
        if l1[0] < l2[0]:
        {
            res.append(l1.pop(0))
        }
        else:
        {    
            res.append(l2.pop(0))
        }
    }

    res.extend(l1)
    res.extend(l2)

    return result
print(merge([16, 36, 57], [27, 48, 68]))
# Out:
#   Cell In[6], line 5
#     {
#     ^
# IndentationError: expected an indented block after 'while' statement on line 4

# %%
#QUESTION 2
employees = ['talha', 'ali', 'irha']
defaults = {"desig": 'Developer', "salary": 8000}
res = dict.fromkeys(employees, defaults)
print(res)
# Out:
# {'Kelly': {'designation': 'Application Developer', 'salary': 8000}, 'Emma': {'designation': 'Application Developer', 'salary': 8000}, 'John': {'designation': 'Application Developer', 'salary': 8000}}

# %%
#QUESTION 3
data = {"name": "talha", "age": 25, "salary": 8000, "city": "lahore"}
remove = ["name", "salary"]
data = {k: data[k] for k in data.keys() - remove}
print(data)
# Out:
# {'age': 25, 'city': 'New york'}

# %%
#QUESTION 4
X = {10, 20, 30, 40}
Y = {30, 40, 50, 60}
res = X ^ Y 
print(res)
# Out:
# {1, 2, 5, 6}

# %%
#QUESTION 5
def division(x, y):
    try:
        result = x / y
        return result
    except ZeroDivisionError:
        return "Divide by zero"
    except TypeError:
        return "Invalid input" 
print(division(10, 2))
# Out:
# 5.0
# Divide by zero
